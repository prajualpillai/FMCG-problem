# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/prajualpillai/Desktop/work/archive/olist_geolocation_dataset.csv")
df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
df2  = pd.read_csv("/Users/prajualpillai/Desktop/work/archive/olist_order_items_dataset.csv")
df2.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
df2.dtypes
# Out:
# order_id                object
# order_item_id            int64
# product_id              object
# seller_id               object
# shipping_limit_date     object
# price                  float64
# freight_value          float64
# dtype: object

# %%
df2["total_cost"] = df2["price"]+df2["freight_value"]
df2.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value  total_cost
# 0  2017-09-19 09:45:35   58.90          13.29       72.19
# 1  2017-05-03 11:05:13  239.90          19.93      259.83
# 2  2018-01-18 14:48:30  199.00          17.87      216.87
# ...

# %%
df2 = df2.sort_values(by="total_cost",ascending=False).reset_index(drop=True)
df2.head()
# Out:
#                            order_id  order_item_id  \
# 0  0812eb902a67711a1cb742b3cdaa65ae              1
# 1  fefacc66af859508bf1a7934eab1e97f              1
# 2  f5136e38d1a14a4dbd87dff67da82701              1
# 3  a96610ab360d42a2e5335a3998b4718a              1
# 4  199af31afc78c699f0dbf71fb178d4d4              1
#
#                          product_id                         seller_id  \
# 0  489ae2aa008f021502940f251d4cce7f  e3b4998c7a498169dc7bce44e6bb6277
# 1  69c590f7ffc7bf8db97190b6cb6ed62e  80ceebb4ee9b31afb6c6a916a574a1e2
# 2  1bdf5e6731585cf01aa8169c7028d6ad  ee27a8f15b1dded4d213a468ba4eb391
# 3  a6492cc69376c469ab6f61d8f44de961  59417c56835dd8e2e72f91f809cd4092
# 4  c3ed642d592594bb648ff4a04cee2747  59417c56835dd8e2e72f91f809cd4092
#
#    shipping_limit_date   price  freight_value  total_cost
# 0  2017-02-16 20:37:36  6735.0         194.31     6929.31
# 1  2018-08-02 04:05:13  6729.0         193.21     6922.21
# 2  2017-06-15 02:45:17  6499.0         227.66     6726.66
# ...

# %%
df3 = pd.read_csv("/Users/prajualpillai/Desktop/work/archive/olist_order_payments_dataset.csv")
df3.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# # Review Analysis

# %%
df4 = pd.read_csv("/Users/prajualpillai/Desktop/work/archive/olist_order_reviews_dataset.csv")
df4.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %% [markdown]
# ## Extracting reviews

# %%
df4.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       88285
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
titles_present = df4[df4["review_comment_title"].isnull()==False]
titles
# Out:
#                               review_id                          order_id  \
# 9      8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
# 15     3948b09f7c818e2d86c9a546758b2335  e51478e7e277a83743b6f9991dbfa3fb
# 19     373cbeecea8286a2b66c97b1b157ec46  583174fbe37d3d5f0d6661be3aad1786
# 22     d21bbc789670eab777d27372ab9094cc  4fc44d78867142c627497b60a7e0228a
# 34     c92cdd7dd544a01aa35137f901669cdf  37e7875cdce5a9e5b3a692971f370151
# ...                                 ...                               ...
# 99967  0e7bc73fde6782891898ea71443f9904  bd78f91afbb1ecbc6124974c5e813043
# 99971  58be140ccdc12e8908ff7fd2ba5c7cb0  0ebf8e35b9807ee2d717922d5663ccdb
# 99972  51de4e06a6b701cb2be47ea0e689437b  b7467ae483dbe956fe9acdf0b1e6e3f4
# 99974  40743b46a0ee86375cedb95e82b78d75  3e93213bb8fdda91186b4018b2fe0030
# 99975  2ee221b28e5b6fceffac59487ed39348  f2d12dd37eaef72ed7b1186b2edefbcd
#
#        review_score       review_comment_title  \
# ...

# %%
import nltk

# %% [markdown]
# # Order List Analysis

# %%
df5 = pd.read_csv("/Users/prajualpillai/Desktop/work/archive/olist_orders_dataset.csv")
df5.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
df5.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
df5.shape
# Out:
# (99441, 8)

# %%
df5.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     371144639291ca32d97aa87af7ef134e  5daa4b042b86596d319e3e78794c0dbe
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-06-01 13:39:44  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %%
df5["order_status"].unique()
# Out:
# array(['delivered', 'invoiced', 'shipped', 'processing', 'unavailable',
#        'canceled', 'created', 'approved'], dtype=object)

# %%
df6 = pd.read_csv("/Users/prajualpillai/Desktop/work/archive/olist_customers_dataset.csv")
df6.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
df7 = pd.merge(df5,df6,on="customer_id")
df7 = pd.merge(df7,df2,on="order_id")
df7.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
df7 = df7.sort_values(by="customer_state")
df7.head()
# Out:
#                                 order_id                       customer_id  \
# 14948   5f9023a84ef9e64c87bc7c1970da5680  6ae24eb8875716251130b7156d33e7ae
# 110476  aaf067f5adccd2b8fdf1a9f651a9148a  62aaae3eaf6f655d97919594b388feaa
# 71435   ca2c921a5b9d60eba417d106c724c6f6  bf21cc881d27bf8909c3922d422cb20e
# 47481   9bad44921c98e1f220a667504bcffb9e  c5de7db594b246f428940ced283125bd
# 39481   573a63f55da869597574d6ce4e1719a3  3b84c81b13c1c7278b099793e720998f
#
#        order_status order_purchase_timestamp    order_approved_at  \
# 14948     delivered      2017-09-12 13:31:54  2017-09-12 15:55:47
# 110476    delivered      2018-06-16 15:30:56  2018-06-17 15:40:49
# 71435     delivered      2018-03-01 18:57:22  2018-03-01 19:15:33
# 47481     delivered      2017-03-05 14:28:33  2017-03-06 14:35:20
# 39481     delivered      2017-04-09 19:12:02  2017-04-10 19:10:13
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# ...

# %%
temp = df7.groupby("customer_state")["total_cost"].sum().sort_values(ascending=False)
temp.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='customer_state'>

# %%
type(temp)
# Out:
# pandas.core.series.Series

# %%
temp.head()
# Out:
# customer_state
# SP    5921678.12
# RJ    2129681.98
# MG    1856161.49
# RS     885826.76
# PR     800935.44
# Name: total_cost, dtype: float64

# %% [markdown]
# ### The states ordering the maximum have also incured the maximum cost as opposed to the other states

# %%
from sklearn.cluster import KMeans
df8 = df7[["customer_id","customer_state","total_cost"]].copy().reset_index(drop=True)
#kmeans = KMeans(n_clusters=5, random_state=0).fit()

# %%
df8
# Out:
#                              customer_id customer_state  total_cost
# 0       6ae24eb8875716251130b7156d33e7ae             AC      100.91
# 1       62aaae3eaf6f655d97919594b388feaa             AC      240.53
# 2       bf21cc881d27bf8909c3922d422cb20e             AC       58.92
# 3       c5de7db594b246f428940ced283125bd             AC      448.30
# 4       3b84c81b13c1c7278b099793e720998f             AC      279.13
# ...                                  ...            ...         ...
# 112645  7fadd7adb85b1f419b8eb907f2159527             TO      122.58
# 112646  27cb4bf5cb4bb383dfe3e61c4b9779d0             TO      214.56
# 112647  a0e89f9dfbebeadd73de6bb72471decf             TO      345.03
# 112648  6433ce3c89daca2222c79192295f8ec4             TO       56.94
# 112649  4e2311c6a3b9c353851097a679ede20a             TO       88.72
#
# [112650 rows x 3 columns]

# %%
plt.plot(df8["total_cost"])
plt.show()

# %%
df8.plot(x="customer_id",y="total_cost",rot=90)
# Out:
# <AxesSubplot:xlabel='customer_id'>
